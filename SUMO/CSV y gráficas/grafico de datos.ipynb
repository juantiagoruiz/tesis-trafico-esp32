# %% [markdown]
# ## Importamos Libraries

# %%
#imports Matplotlib library and assigns shorthand 'plt'
import matplotlib.pyplot as plt
#imports Seaborn library and assigns shorthand 'sns'
import seaborn as sns
#imports Plotly library and assigns shorthand 'px'
#import plotly.express as px
import pandas as pd
import numpy as np

# %%
def generate_bar_traveltime():
    
    Tiempo_viaje_1_L = 75.64
    Tiempo_viaje_2_L = 91.64
    Tiempo_viaje_3_L = 73.02

    Tiempo_viaje_1_M = 80.74
    Tiempo_viaje_2_M = 97.37
    Tiempo_viaje_3_M = 77.70

    Tiempo_viaje_1_H = 83.39
    Tiempo_viaje_2_H = 98.16
    Tiempo_viaje_3_H = 80.75

    algoritmos = ['AACA','ATF','ACAB']
    
    promedios_L = [Tiempo_viaje_1_L,Tiempo_viaje_2_L,Tiempo_viaje_3_L]
    promedios_M = [Tiempo_viaje_1_M,Tiempo_viaje_2_M,Tiempo_viaje_3_M ]
    promedios_H = [Tiempo_viaje_1_H,Tiempo_viaje_2_H,Tiempo_viaje_3_H ] 
    print("Mejora frente al algoritmo ATF por densidad")
    print(((Tiempo_viaje_3_H+Tiempo_viaje_1_H)/2)/Tiempo_viaje_2_H)
    print(((Tiempo_viaje_3_M+Tiempo_viaje_1_M)/2)/Tiempo_viaje_2_M)
    print(((Tiempo_viaje_3_L+Tiempo_viaje_1_L)/2)/Tiempo_viaje_2_L)
    print("Mejora frente al algoritmo ATF total")
    print(((((Tiempo_viaje_3_H+Tiempo_viaje_1_H)/2)/Tiempo_viaje_2_H)+(((Tiempo_viaje_3_M+Tiempo_viaje_1_M)/2)/Tiempo_viaje_2_M)+(((Tiempo_viaje_3_L+Tiempo_viaje_1_L)/2)/Tiempo_viaje_2_L))/3)
    
    x = np.arange(len(algoritmos))
    width = 0.2
    plt.figure(figsize=(10,6), dpi=600)
    plt.bar(x-width/2-width/2, promedios_L,width,label='Densidad trafico baja')
    plt.bar(x, promedios_M,width,label='Densidad trafico media')
    plt.bar(x+width/2+width/2, promedios_H,width,label='Densidad trafico alta')

    plt.xticks(x, algoritmos)
    plt.legend()
    plt.title('Promedio de tiempo de viaje')
    plt.ylabel('Duración de viaje en segundos')
    plt.xlabel('Algoritmos')
    plt.ylim(0,130)
    plt.grid()
    plt.show()

generate_bar_traveltime()
# Out:
# Mejora frente al algoritmo ATF por densidad
# 0.836083944580277
# 0.813597617335935
# 0.8111086861632475
# Mejora frente al algoritmo ATF total
# 0.8202634160264864

# %%
def generate_graphs(data_1, data_2, data_3, variable):

    # Load the dataset into a Pandas DataFrame
    df_1_light = pd.read_csv(data_1)
    variable = variable

    # Rename the column to remove an additional space
    #df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

    # Extract the date and close price columns
    step_history = df_1_light['step_history']
    variable_history = df_1_light[variable]

    # Create a line plot
    plt.plot(step_history/20, variable_history,label='AACA')
    if variable == 'emissions_history':
        plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
        plt.ylabel('Emisiones de CO2 en g/s')
    plt.xlabel('Segundos de simulación')

    df_2_light = pd.read_csv(data_2)

    # Rename the column to remove an additional space
    #df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

    # Extract the date and close price columns
    step_history = df_2_light['step_history']
    variable_history = df_2_light[variable]
    # Create a line plot
    plt.plot(step_history/20, variable_history,label='ACAB')
    if variable == 'emissions_history':
        plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
        plt.ylabel('Emisiones de CO2 en g/s')
    plt.xlabel('Segundos de simulación')


    df_3_light = pd.read_csv(data_3)

    # Extract the date and close price columns
    step_history = df_3_light['step_history']
    variable_history = df_3_light[variable]
    # Create a line plot
    plt.plot(step_history/20, variable_history,label='ATF')
    if variable == 'emissions_history':
        plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
        plt.ylabel('Emisiones de CO2 en g/s')
    plt.xlabel('Segundos de simulación')
    plt.legend()
    plt.show

    print(df_1_light[variable].mean())
    print(df_2_light[variable].mean())
    print(df_3_light[variable].mean())
    plt.figure(figsize=(10,6), dpi=600)
    algoritmos = ['ATF', 'AACA', 'ACAB']
    promedio = [df_2_light[variable].mean(),df_1_light[variable].mean(), df_3_light[variable].mean()]
    plt.bar(algoritmos,promedio)
    if variable == 'emissions_history':
        plt.title('Promedio de emisiones de CO2 sobre tiempo simulado')
        plt.ylabel('Emisiones de CO2 en g/s')
    plt.xlabel('Algoritmos')
    plt.ylabel('Espera en segundos total')
    plt.show()

# %%
def generate_boxplots(data_1, data_2, data_3, variable):

    # Load the dataset into a Pandas DataFrame
    df_1_light = pd.read_csv(data_1)
    variable = variable

    # Rename the column to remove an additional space
    #df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

    # Extract the date and close price columns
    step_history = df_1_light['step_history']
    variable_history = df_1_light[variable]

    # Create a line plot
    plt.plot(step_history/20, variable_history)
    plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
    plt.xlabel('Segundos de simulación')
    plt.ylabel('Emisiones de CO2 en g/s')

    df_2_light = pd.read_csv(data_2)

    # Rename the column to remove an additional space
    #df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

    # Extract the date and close price columns
    step_history = df_2_light['step_history']
    variable_history = df_2_light[variable]
    # Create a line plot
    plt.plot(step_history/20, variable_history)
    plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
    plt.xlabel('Segundos de simulación')
    plt.ylabel('Emisiones de CO2 en g/s')

    df_3_light = pd.read_csv(data_3)

    # Extract the date and close price columns
    step_history = df_3_light['step_history']
    variable_history = df_3_light[variable]
    # Create a line plot
    plt.plot(step_history/20, variable_history)
    plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
    plt.xlabel('Segundos de simulación')
    plt.ylabel('Emisiones de CO2 en g/s')
    plt.show

    print(df_1_light[variable].mean())
    print(df_2_light[variable].mean())
    print(df_3_light[variable].mean())
    #plt.figure()
    #algoritmos = ['ATF', 'AACA', 'ACSG']
    #promedio = [df_2_light[variable].mean(),df_1_light[variable].mean(), df_3_light[variable].mean()]
    #plt.bar(algoritmos,promedio)
    #plt.title('Promedio de tiempo acumulado de espera')
    #plt.xlabel('Algoritmos')
    #plt.ylabel('Espera en segundos total')
    #plt.show()

    df = pd.DataFrame({
        'Algoritmo AACA': df_1_light[variable],
        'Algoritmo ATF': df_2_light[variable],
        'Algoritmo ACAB': df_3_light[variable]
    })

    print(df)
    plt.figure()
    boxplot = df.boxplot(column=['Algoritmo AACA', 'Algoritmo ATF', 'Algoritmo ACAB'])
    plt.title('Boxplot de vehicle_history para los tres algoritmos')
    plt.ylabel('vehicle_history')
    plt.show()

# %%
def generate_bar(data_1_L,data_1_M,data_1_H, data_2_L,data_2_M,data_2_H, data_3_L,data_3_M,data_3_H, variable):
    variable = variable
    # Load the dataset into a Pandas DataFrame
    df_1_light = pd.read_csv(data_1_L)
    df_2_light = pd.read_csv(data_2_L)
    df_3_light = pd.read_csv(data_3_L)

    df_1_med = pd.read_csv(data_1_M)
    df_2_med = pd.read_csv(data_2_M)
    df_3_med = pd.read_csv(data_3_M)

    df_1_heavy = pd.read_csv(data_1_H)
    df_2_heavy = pd.read_csv(data_2_H)
    df_3_heavy = pd.read_csv(data_3_H)


    step_history1_L = df_1_light['step_history']
    step_history2_L = df_2_light['step_history']
    step_history3_L = df_3_light['step_history']

    variable_history1L = df_1_light[variable]
    variable_history2L = df_2_light[variable]
    variable_history3L = df_3_light[variable]

    step_history1_M = df_1_med['step_history']
    step_history2_M = df_2_med['step_history']
    step_history3_M = df_3_med['step_history']

    variable_history1M = df_1_med[variable]
    variable_history2M = df_2_med[variable]
    variable_history3M = df_3_med[variable]

    step_history1_H = df_1_heavy['step_history']
    step_history2_H = df_2_heavy['step_history']
    step_history3_H = df_3_heavy['step_history']

    variable_history1H = df_1_heavy[variable]
    variable_history2H = df_2_heavy[variable]
    variable_history3H = df_3_heavy[variable]


    algoritmos = ['AACA','ATF','ACAB']
    
    promedios_L = [df_1_light[variable].mean(),df_2_light[variable].mean(),df_3_light[variable].mean()]
    promedios_M = [df_1_med[variable].mean(),df_2_med[variable].mean(),df_3_med[variable].mean()]
    promedios_H = [df_1_heavy[variable].mean(),df_2_heavy[variable].mean(),df_3_heavy[variable].mean()] 
    
    if variable == 'waiting_history':
        promedios_L = [df_1_light[variable].mean()/20,df_2_light[variable].mean()/20,df_3_light[variable].mean()/20]
        promedios_M = [df_1_med[variable].mean()/20,df_2_med[variable].mean()/20,df_3_med[variable].mean()/20]
        promedios_H = [df_1_heavy[variable].mean()/20,df_2_heavy[variable].mean()/20,df_3_heavy[variable].mean()/20]
    print("Mejora frente al algoritmo ATF por densidad")
    print(((df_1_heavy[variable].mean()+df_3_heavy[variable].mean())/2)/df_2_heavy[variable].mean())
    print(((df_1_med[variable].mean()+df_3_med[variable].mean())/2)/df_2_med[variable].mean())
    print(((df_1_light[variable].mean()+df_3_light[variable].mean())/2)/df_2_light[variable].mean())
    print("Mejora frente al algoritmo ATF total")
    print(((((df_1_heavy[variable].mean()+df_3_heavy[variable].mean())/2)/df_2_heavy[variable].mean())+(((df_1_med[variable].mean()+df_3_med[variable].mean())/2)/df_2_med[variable].mean())+(((df_1_light[variable].mean()+df_3_light[variable].mean())/2)/df_2_light[variable].mean()))/3)
    x = np.arange(len(algoritmos))
    width = 0.2
    plt.figure(figsize=(10,6), dpi=600)
    plt.bar(x-width/2-width/2, promedios_L,width,label='Densidad trafico baja')
    plt.bar(x, promedios_M,width,label='Densidad trafico media')
    plt.bar(x+width/2+width/2, promedios_H,width,label='Densidad trafico alta')
    plt.xticks(x, algoritmos)
    plt.legend()
    if variable == 'emissions_history':
        plt.title('Promedio de emisiones de CO2 sobre tiempo simulado')
        plt.ylabel('Emisiones de CO2 en g/s')
        plt.ylim(0, 550)  # Set upper limit to 520
    
    if variable == 'waiting_history':
        plt.title('Promedio de tiempo acumulado de espera')
        plt.ylabel('Espera en segundos total')

    if variable == 'queue_history':
        plt.title('Promedio de cantidad de autos en cola')
        plt.ylabel('Cantidad de autos en espera total')

    if variable == 'vehicle_history':
        plt.title('Promedio de cantidad de autos activos en simulación')
        plt.ylabel('Cantidad de autos activos')
    plt.xlabel('Algoritmos')
    plt.grid()
    plt.show()

generate_bar("emissions_dataDF1_light.csv","emissions_dataDF1_med.csv","emissions_dataDF1_heavy.csv","emissions_dataDF2_light.csv","emissions_dataDF2_med.csv","emissions_dataDF2_heavy.csv","emissions_dataDF3_light.csv","emissions_dataDF3_med.csv","emissions_dataDF3_heavy.csv",'emissions_history')
generate_bar("Queue_HistoryDF1_light.csv","Queue_HistoryDF1_med.csv","Queue_HistoryDF1_heavy.csv","Queue_HistoryDF2_light.csv","Queue_HistoryDF2_med.csv","Queue_HistoryDF2_heavy.csv","Queue_HistoryDF3_light.csv","Queue_HistoryDF3_med.csv","Queue_HistoryDF3_heavy.csv",'queue_history')
generate_bar("vehicle_dataDF1_light.csv","vehicle_dataDF1_med.csv","vehicle_dataDF1_heavy.csv","vehicle_dataDF2_light.csv","vehicle_dataDF2_med.csv","vehicle_dataDF2_heavy.csv","vehicle_dataDF3_light.csv","vehicle_dataDF3_med.csv","vehicle_dataDF3_heavy.csv",'vehicle_history')
generate_bar("waiting_dataDF1_light.csv","waiting_dataDF1_med.csv","waiting_dataDF1_heavy.csv","waiting_dataDF2_light.csv","waiting_dataDF2_med.csv","waiting_dataDF2_heavy.csv","waiting_dataDF3_light.csv","waiting_dataDF3_med.csv","waiting_dataDF3_heavy.csv",'waiting_history')
# Out:
# Mejora frente al algoritmo ATF por densidad
# 0.9525664372896508
# 0.9428855578836939
# 0.9434190750200652
# Mejora frente al algoritmo ATF total
# 0.9462903567311366
# Mejora frente al algoritmo ATF por densidad
# 0.7457374508167401
# 0.6731786033097577
# 0.5940639269406393
# Mejora frente al algoritmo ATF total
# 0.670993327022379
# Mejora frente al algoritmo ATF por densidad
# 0.8384964843393297
# 0.8149346236442221
# 0.8105763141228627
# Mejora frente al algoritmo ATF total
# 0.8213358073688047
# Mejora frente al algoritmo ATF por densidad
# 0.43081939231279354
# 0.42324483249823114
# 0.40559759894763514
# Mejora frente al algoritmo ATF total
# 0.41988727458621994

# %%
generate_graphs("emissions_dataDF1_light.csv","emissions_dataDF2_light.csv","emissions_dataDF3_light.csv",'emissions_history')
generate_graphs("emissions_dataDF1_med.csv","emissions_dataDF2_med.csv","emissions_dataDF3_med.csv",'emissions_history')
generate_graphs("emissions_dataDF1_heavy.csv","emissions_dataDF2_heavy.csv","emissions_dataDF3_heavy.csv",'emissions_history')

generate_boxplots("emissions_dataDF1_heavy.csv","emissions_dataDF2_heavy.csv","emissions_dataDF3_heavy.csv",'emissions_history')
# Out:
# 258.2515044958452
# 268.0016852240136
# 247.42429945986996
# D:\Users\Tiago.DESKTOP-Q168LJK\AppData\Local\Temp\ipykernel_17328\3678328863.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 380.337596029705
# 398.10041996749294
# 370.38867711985984
# D:\Users\Tiago.DESKTOP-Q168LJK\AppData\Local\Temp\ipykernel_17328\3678328863.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 443.60461782166357
# 462.4619642533471
# 437.44687351990586
# D:\Users\Tiago.DESKTOP-Q168LJK\AppData\Local\Temp\ipykernel_17328\3678328863.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("emissions_dataDF1_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['emissions_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("emissions_dataDF2_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("emissions_dataDF3_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_light['emissions_history'].mean())
print(df_emissions_2_light['emissions_history'].mean())
print(df_emissions_3_light['emissions_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['emissions_history'].mean(),df_emissions_1_light['emissions_history'].mean(), df_emissions_3_light['emissions_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# 258.2515044958452
# 268.0016852240136
# 247.42429945986996

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_med = pd.read_csv("emissions_dataDF1_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_med['step_history']
emissions_history = df_emissions_1_med['emissions_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico medio algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_med = pd.read_csv("emissions_dataDF2_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_med['step_history']
emissions_history = df_emissions_2_med['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_med = pd.read_csv("emissions_dataDF3_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_med['step_history']
emissions_history = df_emissions_3_med['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_med['emissions_history'].mean())
print(df_emissions_2_med['emissions_history'].mean())
print(df_emissions_3_med['emissions_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_med['emissions_history'].mean(),df_emissions_1_med['emissions_history'].mean(), df_emissions_3_med['emissions_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# 380.337596029705
# 398.10041996749294
# 370.38867711985984

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_heavy = pd.read_csv("emissions_dataDF1_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_heavy['step_history']
emissions_history = df_emissions_1_heavy['emissions_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico pesado algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_heavy = pd.read_csv("emissions_dataDF2_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_heavy['step_history']
emissions_history = df_emissions_2_heavy['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico pesado algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_heavy = pd.read_csv("emissions_dataDF3_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_heavy['step_history']
emissions_history = df_emissions_3_heavy['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_heavy['emissions_history'].mean())
print(df_emissions_2_heavy['emissions_history'].mean())
print(df_emissions_3_heavy['emissions_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_heavy['emissions_history'].mean(),df_emissions_1_heavy['emissions_history'].mean(), df_emissions_3_heavy['emissions_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# 443.60461782166357
# 462.4619642533471
# 437.44687351990586

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("Queue_HistoryDF1_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['queue_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("Queue_HistoryDF2_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['queue_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("Queue_HistoryDF3_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['queue_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_light['queue_history'].mean())
print(df_emissions_2_light['queue_history'].mean())
print(df_emissions_3_light['queue_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['queue_history'].mean(),df_emissions_1_light['queue_history'].mean(), df_emissions_3_light['queue_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# 15.135
# 24.6375
# 14.1375

# %%
# Load the dataset into a Pandas DataFrame
df_queue_1_light = pd.read_csv("Queue_HistoryDF1_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_queue_1_light['step_history']
emissions_history = df_queue_1_light['emissions_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_queue_2_light = pd.read_csv("emissions_dataDF2_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_queue_2_light['step_history']
emissions_history = df_queue_2_light['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_queue_3_light = pd.read_csv("emissions_dataDF3_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_queue_3_light['step_history']
emissions_history = df_queue_3_light['emissions_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_queue_3_light['emissions_history'].mean())
print(df_queue_3_light['emissions_history'].mean())
print(df_queue_3_light['emissions_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_queue_2_light['emissions_history'].mean(),df_queue_1_light['emissions_history'].mean(), df_queue_3_light['emissions_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Users\Tiago.DESKTOP-Q168LJK\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'emissions_history'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 9
# ...

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("Queue_HistoryDF1_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['queue_history']

# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("Queue_HistoryDF2_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['queue_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("Queue_HistoryDF3_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['queue_history']
# Create a line plot
plt.plot(step_history/20, emissions_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_light['queue_history'].mean())
print(df_emissions_2_light['queue_history'].mean())
print(df_emissions_3_light['queue_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['queue_history'].mean(),df_emissions_1_light['queue_history'].mean(), df_emissions_3_light['queue_history'].mean()]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de emisiones de CO2 por segundo')
plt.xlabel('Algoritmos')
plt.ylabel('Emisiones CO2 g/s')
plt.show()
# Out:
# 32.1675
# 41.935
# 30.3775

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("waiting_dataDF1_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['waiting_history']

# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("waiting_dataDF2_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("waiting_dataDF3_heavy.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Tiempo de espera acumulado')
plt.xlabel('Segundos de simulación')
plt.ylabel('Tiempo de espera acumulado (todos los vehiculos)')
plt.show

print(df_emissions_1_light['waiting_history'].mean())
print(df_emissions_2_light['waiting_history'].mean())
print(df_emissions_3_light['waiting_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['waiting_history'].mean()/20,df_emissions_1_light['waiting_history'].mean()/20, df_emissions_3_light['waiting_history'].mean()/20]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de tiempo acumulado de espera')
plt.xlabel('Algoritmos')
plt.ylabel('Espera en segundos total')
plt.show()
# Out:
# 194496.61
# 489770.3075
# 227508.4825

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("waiting_dataDF1_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['waiting_history']

# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("waiting_dataDF2_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("waiting_dataDF3_med.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_light['waiting_history'].mean())
print(df_emissions_2_light['waiting_history'].mean())
print(df_emissions_3_light['waiting_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['waiting_history'].mean()/20,df_emissions_1_light['waiting_history'].mean()/20, df_emissions_3_light['waiting_history'].mean()/20]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de tiempo acumulado de espera')
plt.xlabel('Algoritmos')
plt.ylabel('Espera en segundos total')
plt.show()
# Out:
# 168740.0125
# 407745.0225
# 176411.935

# %%
# Load the dataset into a Pandas DataFrame
df_emissions_1_light = pd.read_csv("waiting_dataDF1_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_1_light['step_history']
emissions_history = df_emissions_1_light['waiting_history']

# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_2_light = pd.read_csv("waiting_dataDF2_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_2_light['step_history']
emissions_history = df_emissions_2_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_emissions_3_light = pd.read_csv("waiting_dataDF3_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_emissions_3_light['step_history']
emissions_history = df_emissions_3_light['waiting_history']
# Create a line plot
plt.plot(step_history/20, emissions_history/20)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_emissions_1_light['waiting_history'].mean())
print(df_emissions_2_light['waiting_history'].mean())
print(df_emissions_3_light['waiting_history'].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio_emisiones = [df_emissions_2_light['waiting_history'].mean()/20,df_emissions_1_light['waiting_history'].mean()/20, df_emissions_3_light['waiting_history'].mean()/20]
plt.bar(algoritmos,promedio_emisiones)
plt.title('Promedio de tiempo acumulado de espera')
plt.xlabel('Algoritmos')
plt.ylabel('Espera en segundos total')
plt.show()
# Out:
# 107368.4625
# 267215.33
# 109395.33

# %%
# Load the dataset into a Pandas DataFrame
df_1_light = pd.read_csv("vehicle_dataDF1_light.csv")
variable = 'vehicle_history'

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_1_light['step_history']
variable_history = df_1_light[variable]

# Create a line plot
plt.plot(step_history/20, variable_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 1')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_2_light = pd.read_csv("vehicle_dataDF2_light.csv")

# Rename the column to remove an additional space
#df = df.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# Extract the date and close price columns
step_history = df_2_light['step_history']
variable_history = df_2_light[variable]
# Create a line plot
plt.plot(step_history/20, variable_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 2')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')

df_3_light = pd.read_csv("vehicle_dataDF3_light.csv")

# Extract the date and close price columns
step_history = df_3_light['step_history']
variable_history = df_3_light[variable]
# Create a line plot
plt.plot(step_history/20, variable_history)
plt.title('Emisiones por tiempo tráfico liviano algoritmo 3')
plt.xlabel('Segundos de simulación')
plt.ylabel('Emisiones de CO2 en g/s')
plt.show

print(df_1_light[variable].mean())
print(df_2_light[variable].mean())
print(df_3_light[variable].mean())
plt.figure()
algoritmos = ['ATF', 'AACA', 'ACSG']
promedio = [df_2_light[variable].mean(),df_1_light[variable].mean(), df_3_light[variable].mean()]
plt.bar(algoritmos,promedio)
plt.title('Promedio de tiempo acumulado de espera')
plt.xlabel('Algoritmos')
plt.ylabel('Espera en segundos total')
plt.show()
# Out:
# 48.7975
# 59.2125
# 47.195

# %%
df = pd.DataFrame({
    'Algoritmo 1': df_1_light['vehicle_history'],
    'Algoritmo 2': df_2_light['vehicle_history'],
    'Algoritmo 3': df_3_light['vehicle_history']
})

print(df)
boxplot = df.boxplot(column=['Algoritmo 1', 'Algoritmo 2', 'Algoritmo 3'])
plt.title('Boxplot de vehicle_history para los tres algoritmos')
plt.ylabel('vehicle_history')
plt.show()
# Out:
#      Algoritmo 1  Algoritmo 2  Algoritmo 3
# 0              3            3            3
# 1              8            8            8
# 2             10           10           10
# 3             14           14           14
# 4             18           18           18
# ..           ...          ...          ...
# 395           55           68           48
# 396           55           59           50
# 397           54           58           53
# 398           56           55           54
# 399           57           56           59
#
# [400 rows x 3 columns]
